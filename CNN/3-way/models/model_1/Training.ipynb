# %%
# !rm -r *
# !add-apt-repository ppa:sumo/stable -y
# !apt-get update -y
# !apt-get install sumo sumo-tools sumo-doc
# !pip install traci
import os
os.environ['SUMO_HOME'] = "/usr/share/sumo/"
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,367 kB]
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [607 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,431 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://ppa.launchpad.net/sumo/stable/ubuntu bionic InRelease [15.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [640 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,803 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,210 kB]
# Get:23 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 Packages [1,159 B]
# Fetched 10.3 MB in 3s (2,978 kB/s)
# Reading package lists... Done
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/sumo/stable/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   binfmt-support fastjar jarwrapper javascript-common libfox-1.6-0
#   libjs-jquery libjs-openlayers libjs-underscore libspatialindex-c4v5
#   libspatialindex-dev libspatialindex4v5 python3-pkg-resources python3-pyproj
#   python3-rtree
# Suggested packages:
#   apache2 | lighttpd | httpd python3-setuptools
# The following NEW packages will be installed:
#   binfmt-support fastjar jarwrapper javascript-common libfox-1.6-0
#   libjs-jquery libjs-openlayers libjs-underscore libspatialindex-c4v5
#   libspatialindex-dev libspatialindex4v5 python3-pkg-resources python3-pyproj
#   python3-rtree sumo sumo-doc sumo-tools
# 0 upgraded, 17 newly installed, 0 to remove and 37 not upgraded.
# Need to get 99.9 MB of archives.
# After this operation, 549 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo amd64 1.10.0+dfsg1-1~bionic [13.9 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 binfmt-support amd64 2.1.8-2 [51.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fastjar amd64 2:0.98-6build1 [66.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 jarwrapper all 0.72.1~18.04.1 [20.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfox-1.6-0 amd64 1.6.56-1 [875 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjs-underscore all 1.8.3~dfsg-1ubuntu0.1 [60.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex4v5 amd64 1.8.5-5 [219 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex-c4v5 amd64 1.8.5-5 [51.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pyproj amd64 1.9.5.1-3build1 [40.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex-dev amd64 1.8.5-5 [285 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-rtree all 0.8.3+ds-1 [16.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-openlayers all 2.13.1+ds2-4 [704 kB]
# Get:16 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo-doc all 1.10.0+dfsg1-1~bionic [62.0 MB]
# Get:17 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo-tools all 1.10.0+dfsg1-1~bionic [21.3 MB]
# Fetched 99.9 MB in 6s (17.9 MB/s)
# Selecting previously unselected package binfmt-support.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../00-binfmt-support_2.1.8-2_amd64.deb ...
# Unpacking binfmt-support (2.1.8-2) ...
# Selecting previously unselected package fastjar.
# Preparing to unpack .../01-fastjar_2%3a0.98-6build1_amd64.deb ...
# Unpacking fastjar (2:0.98-6build1) ...
# Selecting previously unselected package jarwrapper.
# Preparing to unpack .../02-jarwrapper_0.72.1~18.04.1_all.deb ...
# Unpacking jarwrapper (0.72.1~18.04.1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../03-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libfox-1.6-0:amd64.
# Preparing to unpack .../04-libfox-1.6-0_1.6.56-1_amd64.deb ...
# Unpacking libfox-1.6-0:amd64 (1.6.56-1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../05-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../06-libjs-underscore_1.8.3~dfsg-1ubuntu0.1_all.deb ...
# Unpacking libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Selecting previously unselected package libspatialindex4v5:amd64.
# Preparing to unpack .../07-libspatialindex4v5_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex4v5:amd64 (1.8.5-5) ...
# Selecting previously unselected package libspatialindex-c4v5:amd64.
# Preparing to unpack .../08-libspatialindex-c4v5_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex-c4v5:amd64 (1.8.5-5) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../09-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-pyproj.
# Preparing to unpack .../10-python3-pyproj_1.9.5.1-3build1_amd64.deb ...
# Unpacking python3-pyproj (1.9.5.1-3build1) ...
# Selecting previously unselected package libspatialindex-dev:amd64.
# Preparing to unpack .../11-libspatialindex-dev_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex-dev:amd64 (1.8.5-5) ...
# Selecting previously unselected package python3-rtree.
# Preparing to unpack .../12-python3-rtree_0.8.3+ds-1_all.deb ...
# Unpacking python3-rtree (0.8.3+ds-1) ...
# Selecting previously unselected package sumo.
# Preparing to unpack .../13-sumo_1.10.0+dfsg1-1~bionic_amd64.deb ...
# Unpacking sumo (1.10.0+dfsg1-1~bionic) ...
# Selecting previously unselected package sumo-doc.
# Preparing to unpack .../14-sumo-doc_1.10.0+dfsg1-1~bionic_all.deb ...
# Unpacking sumo-doc (1.10.0+dfsg1-1~bionic) ...
# Selecting previously unselected package libjs-openlayers.
# Preparing to unpack .../15-libjs-openlayers_2.13.1+ds2-4_all.deb ...
# Unpacking libjs-openlayers (2.13.1+ds2-4) ...
# Selecting previously unselected package sumo-tools.
# Preparing to unpack .../16-sumo-tools_1.10.0+dfsg1-1~bionic_all.deb ...
# Unpacking sumo-tools (1.10.0+dfsg1-1~bionic) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up binfmt-support (2.1.8-2) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/binfmt-support.service → /lib/systemd/system/binfmt-support.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libspatialindex4v5:amd64 (1.8.5-5) ...
# Setting up libfox-1.6-0:amd64 (1.6.56-1) ...
# Setting up libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Setting up fastjar (2:0.98-6build1) ...
# Setting up libjs-openlayers (2.13.1+ds2-4) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up sumo (1.10.0+dfsg1-1~bionic) ...
# Setting up libspatialindex-c4v5:amd64 (1.8.5-5) ...
# Setting up python3-pyproj (1.9.5.1-3build1) ...
# Setting up javascript-common (11) ...
# Setting up jarwrapper (0.72.1~18.04.1) ...
# Setting up sumo-doc (1.10.0+dfsg1-1~bionic) ...
# Setting up libspatialindex-dev:amd64 (1.8.5-5) ...
# Setting up python3-rtree (0.8.3+ds-1) ...
# Setting up sumo-tools (1.10.0+dfsg1-1~bionic) ...
# Processing triggers for systemd (237-3ubuntu10.52) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting traci
#   Downloading traci-1.10.0-py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 2.6 MB/s
# Collecting sumolib>=1.10.0
#   Downloading sumolib-1.10.0-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 18.2 MB/s
# Installing collected packages: sumolib, traci
# Successfully installed sumolib-1.10.0 traci-1.10.0

# %%
# !python training_main.py
# Out:
# 2021-10-13 08:59:26.340688: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#
# ----- Episode 1 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.45 for vehicle 'B_A760' to match departure speed.
# Warning: Choosing new speed factor 1.74 for vehicle 'A_C791' to match departure speed.
# Warning: Choosing new speed factor 1.42 for vehicle 'B_A891' to match departure speed.
# Total reward: -12353.0 - Epsilon: 1.0
# Training...
# Simulation time: 4.4 s - Training time: 0.0 s - Total: 4.4 s
#
# ----- Episode 2 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.43 for vehicle 'C_B305' to match departure speed.
# Warning: Choosing new speed factor 1.52 for vehicle 'B_C678' to match departure speed.
# Total reward: -12493.0 - Epsilon: 0.97
# Training...
# Simulation time: 5.5 s - Training time: 575.8 s - Total: 581.3 s
#
# ----- Episode 3 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.48 for vehicle 'A_C470' to match departure speed.
# Warning: Choosing new speed factor 1.40 for vehicle 'A_C713' to match departure speed.
# Warning: Choosing new speed factor 1.46 for vehicle 'A_C827' to match departure speed.
# Warning: Choosing new speed factor 1.48 for vehicle 'C_B851' to match departure speed.
# Total reward: -15184.0 - Epsilon: 0.93
# Training...
# Simulation time: 6.9 s - Training time: 573.1 s - Total: 580.0 s
#
# ----- Episode 4 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.52 for vehicle 'C_A760' to match departure speed.
# Warning: Choosing new speed factor 1.46 for vehicle 'B_A826' to match departure speed.
# Total reward: -10980.0 - Epsilon: 0.9
# Training...
# Simulation time: 8.1 s - Training time: 559.1 s - Total: 567.2 s
#
# ----- Episode 5 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.80 for vehicle 'PC_B8' to match departure speed.
# Warning: Choosing new speed factor 1.50 for vehicle 'A_B228' to match departure speed.
# Warning: Choosing new speed factor 1.40 for vehicle 'C_A700' to match departure speed.
# Warning: Choosing new speed factor 1.52 for vehicle 'B_A760' to match departure speed.
# Warning: Choosing new speed factor 1.48 for vehicle 'C_A914' to match departure speed.
# Total reward: -9078.0 - Epsilon: 0.87
# Training...
# Simulation time: 8.4 s - Training time: 564.3 s - Total: 572.7 s
#
# ----- Episode 6 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.45 for vehicle 'A_B279' to match departure speed.
# Warning: Choosing new speed factor 1.48 for vehicle 'B_C819' to match departure speed.
# Warning: Choosing new speed factor 1.48 for vehicle 'B_C894' to match departure speed.
# Total reward: -10028.0 - Epsilon: 0.83
# Training...
# Simulation time: 9.1 s - Training time: 562.3 s - Total: 571.4 s
#
# ----- Episode 7 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.53 for vehicle 'A_B203' to match departure speed.
# Warning: Choosing new speed factor 1.51 for vehicle 'B_C502' to match departure speed.
# Warning: Choosing new speed factor 1.60 for vehicle 'C_B510' to match departure speed.
# Total reward: -9422.0 - Epsilon: 0.8
# Training...
# Simulation time: 10.5 s - Training time: 561.6 s - Total: 572.1 s
#
# ----- Episode 8 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.42 for vehicle 'A_C632' to match departure speed.
# Warning: Choosing new speed factor 1.52 for vehicle 'B_C676' to match departure speed.
# Warning: Choosing new speed factor 1.46 for vehicle 'B_A825' to match departure speed.
# Total reward: -11953.0 - Epsilon: 0.77
# Training...
# Simulation time: 11.5 s - Training time: 565.4 s - Total: 576.9 s
#
# ----- Episode 9 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -10816.0 - Epsilon: 0.73
# Training...
# Simulation time: 11.7 s - Training time: 557.0 s - Total: 568.7 s
#
# ----- Episode 10 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.45 for vehicle 'A_C279' to match departure speed.
# Warning: Choosing new speed factor 1.51 for vehicle 'B_A502' to match departure speed.
# Warning: Choosing new speed factor 1.60 for vehicle 'C_B510' to match departure speed.
# Warning: Choosing new speed factor 1.48 for vehicle 'B_A914' to match departure speed.
# Total reward: -9025.0 - Epsilon: 0.7
# Training...
# Simulation time: 11.5 s - Training time: 553.9 s - Total: 565.4 s
#
# ----- Episode 11 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.52 for vehicle 'PA_C765' to match departure speed.
# Warning: Choosing new speed factor 1.46 for vehicle 'C_B826' to match departure speed.
# Total reward: -6186.0 - Epsilon: 0.67
# Training...
# Simulation time: 12.1 s - Training time: 555.8 s - Total: 567.9 s
#
# ----- Episode 12 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.45 for vehicle 'B_A276' to match departure speed.
# Warning: Choosing new speed factor 1.51 for vehicle 'B_A508' to match departure speed.
# Warning: Choosing new speed factor 1.60 for vehicle 'C_A518' to match departure speed.
# Total reward: -7236.0 - Epsilon: 0.63
# Training...
# Simulation time: 12.5 s - Training time: 558.2 s - Total: 570.7 s
#
# ----- Episode 13 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.42 for vehicle 'C_B899' to match departure speed.
# Warning: Choosing new speed factor 1.47 for vehicle 'A_C954' to match departure speed.
# Total reward: -8694.0 - Epsilon: 0.6
# Training...
# Simulation time: 13.6 s - Training time: 554.8 s - Total: 568.4 s
#
# ----- Episode 14 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.52 for vehicle 'C_A661' to match departure speed.
# Total reward: -6425.0 - Epsilon: 0.57
# Training...
# Simulation time: 14.5 s - Training time: 565.9 s - Total: 580.4 s
#
# ----- Episode 15 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.45 for vehicle 'B_A360' to match departure speed.
# Warning: Choosing new speed factor 1.43 for vehicle 'C_B894' to match departure speed.
# Total reward: -5962.0 - Epsilon: 0.53
# Training...
# Simulation time: 15.1 s - Training time: 559.9 s - Total: 575.0 s
#
# ----- Episode 16 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.46 for vehicle 'A_C827' to match departure speed.
# Total reward: -6345.0 - Epsilon: 0.5
# Training...
# Simulation time: 16.3 s - Training time: 556.8 s - Total: 573.1 s
#
# ----- Episode 17 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.53 for vehicle 'C_A203' to match departure speed.
# Warning: Choosing new speed factor 1.50 for vehicle 'B_A339' to match departure speed.
# Warning: Choosing new speed factor 1.41 for vehicle 'A_C574' to match departure speed.
# Warning: Choosing new speed factor 1.48 for vehicle 'B_A851' to match departure speed.
# Total reward: -4850.0 - Epsilon: 0.47
# Training...
# Simulation time: 16.7 s - Training time: 558.8 s - Total: 575.5 s
#
# ----- Episode 18 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.41 for vehicle 'A_B574' to match departure speed.
# Warning: Choosing new speed factor 1.42 for vehicle 'C_A634' to match departure speed.
# Total reward: -5932.0 - Epsilon: 0.43
# Training...
# Simulation time: 16.6 s - Training time: 557.2 s - Total: 573.8 s
#
# ----- Episode 19 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.52 for vehicle 'C_B661' to match departure speed.
# Total reward: -5437.0 - Epsilon: 0.4
# Training...
# Simulation time: 17.8 s - Training time: 555.6 s - Total: 573.4 s
#
# ----- Episode 20 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.43 for vehicle 'C_B305' to match departure speed.
# Warning: Choosing new speed factor 1.41 for vehicle 'B_A574' to match departure speed.
# Warning: Choosing new speed factor 1.40 for vehicle 'B_A713' to match departure speed.
# Total reward: -5145.0 - Epsilon: 0.37
# Training...
# Simulation time: 17.2 s - Training time: 555.9 s - Total: 573.1 s
#
# ----- Episode 21 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.53 for vehicle 'B_C203' to match departure speed.
# Warning: Choosing new speed factor 1.50 for vehicle 'A_C228' to match departure speed.
# Warning: Choosing new speed factor 1.48 for vehicle 'B_A470' to match departure speed.
# Warning: Choosing new speed factor 1.52 for vehicle 'C_A770' to match departure speed.
# Total reward: -4742.0 - Epsilon: 0.33
# Training...
# Simulation time: 19.8 s - Training time: 568.8 s - Total: 588.6 s
#
# ----- Episode 22 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.46 for vehicle 'A_C510' to match departure speed.
# Warning: Choosing new speed factor 1.42 for vehicle 'A_C891' to match departure speed.
# Total reward: -4510.0 - Epsilon: 0.3
# Training...
# Simulation time: 20.6 s - Training time: 562.4 s - Total: 583.0 s
#
# ----- Episode 23 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.52 for vehicle 'B_C760' to match departure speed.
# Warning: Choosing new speed factor 1.46 for vehicle 'A_C819' to match departure speed.
# Warning: Choosing new speed factor 1.42 for vehicle 'B_C880' to match departure speed.
# Total reward: -3570.0 - Epsilon: 0.27
# Training...
# Simulation time: 20.7 s - Training time: 560.7 s - Total: 581.4 s
#
# ----- Episode 24 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.47 for vehicle 'C_A947' to match departure speed.
# Total reward: -4414.0 - Epsilon: 0.23
# Training...
# Simulation time: 20.4 s - Training time: 562.6 s - Total: 583.0 s
#
# ----- Episode 25 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.46 for vehicle 'C_A823' to match departure speed.
# Total reward: -3761.0 - Epsilon: 0.2
# Training...
# Simulation time: 21.0 s - Training time: 563.2 s - Total: 584.2 s
#
# ----- Episode 26 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.45 for vehicle 'B_C276' to match departure speed.
# Warning: Choosing new speed factor 1.52 for vehicle 'B_C669' to match departure speed.
# Warning: Choosing new speed factor 1.40 for vehicle 'B_C700' to match departure speed.
# Warning: Choosing new speed factor 1.46 for vehicle 'B_C819' to match departure speed.
# Warning: Choosing new speed factor 1.42 for vehicle 'C_B880' to match departure speed.
# Total reward: -4161.0 - Epsilon: 0.17
# Training...
# Simulation time: 21.1 s - Training time: 560.8 s - Total: 581.9 s
#
# ----- Episode 27 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.52 for vehicle 'C_A669' to match departure speed.
# Warning: Choosing new speed factor 1.45 for vehicle 'C_B757' to match departure speed.
# Total reward: -3929.0 - Epsilon: 0.13
# Training...
# Simulation time: 23.8 s - Training time: 583.3 s - Total: 607.1 s
#
# ----- Episode 28 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.45 for vehicle 'A_B279' to match departure speed.
# Total reward: -3368.0 - Epsilon: 0.1
# Training...
# Simulation time: 24.5 s - Training time: 569.1 s - Total: 593.6 s
#
# ----- Episode 29 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.43 for vehicle 'B_A305' to match departure speed.
# Warning: Choosing new speed factor 1.41 for vehicle 'C_B574' to match departure speed.
# Warning: Choosing new speed factor 1.95 for vehicle 'PC_B858' to match departure speed.
# Warning: Choosing new speed factor 1.84 for vehicle 'PC_B898' to match departure speed.
# Total reward: -2910.0 - Epsilon: 0.07
# Training...
# Simulation time: 24.2 s - Training time: 562.5 s - Total: 586.7 s
#
# ----- Episode 30 of 30
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Warning: Choosing new speed factor 1.45 for vehicle 'C_A276' to match departure speed.
# Warning: Choosing new speed factor 1.48 for vehicle 'A_C827' to match departure speed.
# Total reward: -2923.0 - Epsilon: 0.03
# Training...
# Simulation time: 24.9 s - Training time: 564.3 s - Total: 589.2 s
#
# ----- Start time: 2021-10-13 08:59:26.537635
# ----- End time: 2021-10-13 13:38:56.513147
# ----- Session info saved at: /content/models/model_1/
