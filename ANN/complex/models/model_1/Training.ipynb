# %%
# !rm -r *
# !add-apt-repository ppa:sumo/stable -y
# !apt-get update -y
# !apt-get install sumo sumo-tools sumo-doc
# !pip install traci
import os
os.environ['SUMO_HOME'] = "/usr/share/sumo/"
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,431 kB]
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,367 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [607 kB]
# Get:17 http://ppa.launchpad.net/sumo/stable/ubuntu bionic InRelease [15.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,210 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [640 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,803 kB]
# Get:23 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 Packages [1,159 B]
# Fetched 10.3 MB in 4s (2,925 kB/s)
# Reading package lists... Done
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/sumo/stable/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   binfmt-support fastjar jarwrapper javascript-common libfox-1.6-0
#   libjs-jquery libjs-openlayers libjs-underscore libspatialindex-c4v5
#   libspatialindex-dev libspatialindex4v5 python3-pkg-resources python3-pyproj
#   python3-rtree
# Suggested packages:
#   apache2 | lighttpd | httpd python3-setuptools
# The following NEW packages will be installed:
#   binfmt-support fastjar jarwrapper javascript-common libfox-1.6-0
#   libjs-jquery libjs-openlayers libjs-underscore libspatialindex-c4v5
#   libspatialindex-dev libspatialindex4v5 python3-pkg-resources python3-pyproj
#   python3-rtree sumo sumo-doc sumo-tools
# 0 upgraded, 17 newly installed, 0 to remove and 37 not upgraded.
# Need to get 99.9 MB of archives.
# After this operation, 549 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 binfmt-support amd64 2.1.8-2 [51.6 kB]
# Get:2 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo amd64 1.10.0+dfsg1-1~bionic [13.9 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fastjar amd64 2:0.98-6build1 [66.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 jarwrapper all 0.72.1~18.04.1 [20.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfox-1.6-0 amd64 1.6.56-1 [875 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjs-underscore all 1.8.3~dfsg-1ubuntu0.1 [60.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex4v5 amd64 1.8.5-5 [219 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex-c4v5 amd64 1.8.5-5 [51.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pyproj amd64 1.9.5.1-3build1 [40.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex-dev amd64 1.8.5-5 [285 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-rtree all 0.8.3+ds-1 [16.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-openlayers all 2.13.1+ds2-4 [704 kB]
# Get:16 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo-doc all 1.10.0+dfsg1-1~bionic [62.0 MB]
# Get:17 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo-tools all 1.10.0+dfsg1-1~bionic [21.3 MB]
# Fetched 99.9 MB in 5s (18.2 MB/s)
# Selecting previously unselected package binfmt-support.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../00-binfmt-support_2.1.8-2_amd64.deb ...
# Unpacking binfmt-support (2.1.8-2) ...
# Selecting previously unselected package fastjar.
# Preparing to unpack .../01-fastjar_2%3a0.98-6build1_amd64.deb ...
# Unpacking fastjar (2:0.98-6build1) ...
# Selecting previously unselected package jarwrapper.
# Preparing to unpack .../02-jarwrapper_0.72.1~18.04.1_all.deb ...
# Unpacking jarwrapper (0.72.1~18.04.1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../03-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libfox-1.6-0:amd64.
# Preparing to unpack .../04-libfox-1.6-0_1.6.56-1_amd64.deb ...
# Unpacking libfox-1.6-0:amd64 (1.6.56-1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../05-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../06-libjs-underscore_1.8.3~dfsg-1ubuntu0.1_all.deb ...
# Unpacking libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Selecting previously unselected package libspatialindex4v5:amd64.
# Preparing to unpack .../07-libspatialindex4v5_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex4v5:amd64 (1.8.5-5) ...
# Selecting previously unselected package libspatialindex-c4v5:amd64.
# Preparing to unpack .../08-libspatialindex-c4v5_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex-c4v5:amd64 (1.8.5-5) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../09-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-pyproj.
# Preparing to unpack .../10-python3-pyproj_1.9.5.1-3build1_amd64.deb ...
# Unpacking python3-pyproj (1.9.5.1-3build1) ...
# Selecting previously unselected package libspatialindex-dev:amd64.
# Preparing to unpack .../11-libspatialindex-dev_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex-dev:amd64 (1.8.5-5) ...
# Selecting previously unselected package python3-rtree.
# Preparing to unpack .../12-python3-rtree_0.8.3+ds-1_all.deb ...
# Unpacking python3-rtree (0.8.3+ds-1) ...
# Selecting previously unselected package sumo.
# Preparing to unpack .../13-sumo_1.10.0+dfsg1-1~bionic_amd64.deb ...
# Unpacking sumo (1.10.0+dfsg1-1~bionic) ...
# Selecting previously unselected package sumo-doc.
# Preparing to unpack .../14-sumo-doc_1.10.0+dfsg1-1~bionic_all.deb ...
# Unpacking sumo-doc (1.10.0+dfsg1-1~bionic) ...
# Selecting previously unselected package libjs-openlayers.
# Preparing to unpack .../15-libjs-openlayers_2.13.1+ds2-4_all.deb ...
# Unpacking libjs-openlayers (2.13.1+ds2-4) ...
# Selecting previously unselected package sumo-tools.
# Preparing to unpack .../16-sumo-tools_1.10.0+dfsg1-1~bionic_all.deb ...
# Unpacking sumo-tools (1.10.0+dfsg1-1~bionic) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up binfmt-support (2.1.8-2) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/binfmt-support.service → /lib/systemd/system/binfmt-support.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libspatialindex4v5:amd64 (1.8.5-5) ...
# Setting up libfox-1.6-0:amd64 (1.6.56-1) ...
# Setting up libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Setting up fastjar (2:0.98-6build1) ...
# Setting up libjs-openlayers (2.13.1+ds2-4) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up sumo (1.10.0+dfsg1-1~bionic) ...
# Setting up libspatialindex-c4v5:amd64 (1.8.5-5) ...
# Setting up python3-pyproj (1.9.5.1-3build1) ...
# Setting up javascript-common (11) ...
# Setting up jarwrapper (0.72.1~18.04.1) ...
# Setting up sumo-doc (1.10.0+dfsg1-1~bionic) ...
# Setting up libspatialindex-dev:amd64 (1.8.5-5) ...
# Setting up python3-rtree (0.8.3+ds-1) ...
# Setting up sumo-tools (1.10.0+dfsg1-1~bionic) ...
# Processing triggers for systemd (237-3ubuntu10.52) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting traci
#   Downloading traci-1.10.0-py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 5.3 MB/s
# Collecting sumolib>=1.10.0
#   Downloading sumolib-1.10.0-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 42.1 MB/s
# Installing collected packages: sumolib, traci
# Successfully installed sumolib-1.10.0 traci-1.10.0

# %%
# !python training_main.py
# Out:
# 2021-10-13 14:22:22.547628: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#
# ----- Episode 1 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -232515.0 - Epsilon: 1.0
# Training...
# Simulation time: 17.7 s - Training time: 0.0 s - Total: 17.7 s
#
# ----- Episode 2 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -250163.0 - Epsilon: 0.98
# Training...
# Simulation time: 21.8 s - Training time: 290.2 s - Total: 312.0 s
#
# ----- Episode 3 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -250287.0 - Epsilon: 0.97
# Training...
# Simulation time: 20.5 s - Training time: 302.2 s - Total: 322.7 s
#
# ----- Episode 4 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -198673.0 - Epsilon: 0.95
# Training...
# Simulation time: 21.1 s - Training time: 304.8 s - Total: 325.9 s
#
# ----- Episode 5 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -255666.0 - Epsilon: 0.93
# Training...
# Simulation time: 26.9 s - Training time: 312.4 s - Total: 339.3 s
#
# ----- Episode 6 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -181566.0 - Epsilon: 0.92
# Training...
# Simulation time: 25.5 s - Training time: 300.3 s - Total: 325.8 s
#
# ----- Episode 7 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -228144.0 - Epsilon: 0.9
# Training...
# Simulation time: 26.5 s - Training time: 297.8 s - Total: 324.3 s
#
# ----- Episode 8 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -192013.0 - Epsilon: 0.88
# Training...
# Simulation time: 24.4 s - Training time: 280.1 s - Total: 304.5 s
#
# ----- Episode 9 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -232062.0 - Epsilon: 0.87
# Training...
# Simulation time: 28.4 s - Training time: 283.4 s - Total: 311.8 s
#
# ----- Episode 10 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -258302.0 - Epsilon: 0.85
# Training...
# Simulation time: 32.9 s - Training time: 288.2 s - Total: 321.1 s
#
# ----- Episode 11 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -239922.0 - Epsilon: 0.83
# Training...
# Simulation time: 30.7 s - Training time: 271.4 s - Total: 302.1 s
#
# ----- Episode 12 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -227584.0 - Epsilon: 0.82
# Training...
# Simulation time: 31.3 s - Training time: 270.4 s - Total: 301.7 s
#
# ----- Episode 13 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -178070.0 - Epsilon: 0.8
# Training...
# Simulation time: 32.8 s - Training time: 270.8 s - Total: 303.6 s
#
# ----- Episode 14 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -163530.0 - Epsilon: 0.78
# Training...
# Simulation time: 36.9 s - Training time: 288.1 s - Total: 325.0 s
#
# ----- Episode 15 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -183201.0 - Epsilon: 0.77
# Training...
# Simulation time: 35.9 s - Training time: 279.1 s - Total: 315.0 s
#
# ----- Episode 16 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -145950.0 - Epsilon: 0.75
# Training...
# Simulation time: 37.2 s - Training time: 283.2 s - Total: 320.4 s
#
# ----- Episode 17 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -177693.0 - Epsilon: 0.73
# Training...
# Simulation time: 40.3 s - Training time: 271.8 s - Total: 312.1 s
#
# ----- Episode 18 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -167901.0 - Epsilon: 0.72
# Training...
# Simulation time: 37.2 s - Training time: 272.7 s - Total: 309.9 s
#
# ----- Episode 19 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -139469.0 - Epsilon: 0.7
# Training...
# Simulation time: 41.5 s - Training time: 293.6 s - Total: 335.1 s
#
# ----- Episode 20 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -150393.0 - Epsilon: 0.68
# Training...
# Simulation time: 39.6 s - Training time: 282.6 s - Total: 322.2 s
#
# ----- Episode 21 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -263831.0 - Epsilon: 0.67
# Training...
# Simulation time: 46.0 s - Training time: 280.6 s - Total: 326.6 s
#
# ----- Episode 22 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -182744.0 - Epsilon: 0.65
# Training...
# Simulation time: 46.1 s - Training time: 287.7 s - Total: 333.8 s
#
# ----- Episode 23 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -168555.0 - Epsilon: 0.63
# Training...
# Simulation time: 51.3 s - Training time: 317.0 s - Total: 368.3 s
#
# ----- Episode 24 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -165477.0 - Epsilon: 0.62
# Training...
# Simulation time: 48.5 s - Training time: 299.1 s - Total: 347.6 s
#
# ----- Episode 25 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -147726.0 - Epsilon: 0.6
# Training...
# Simulation time: 49.9 s - Training time: 300.9 s - Total: 350.8 s
#
# ----- Episode 26 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -139811.0 - Epsilon: 0.58
# Training...
# Simulation time: 47.9 s - Training time: 296.1 s - Total: 344.0 s
#
# ----- Episode 27 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -129353.0 - Epsilon: 0.57
# Training...
# Simulation time: 50.0 s - Training time: 286.2 s - Total: 336.2 s
#
# ----- Episode 28 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -101899.0 - Epsilon: 0.55
# Training...
# Simulation time: 50.8 s - Training time: 301.3 s - Total: 352.1 s
#
# ----- Episode 29 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -142477.0 - Epsilon: 0.53
# Training...
# Simulation time: 51.8 s - Training time: 289.2 s - Total: 341.0 s
#
# ----- Episode 30 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -127501.0 - Epsilon: 0.52
# Training...
# Simulation time: 52.8 s - Training time: 293.0 s - Total: 345.8 s
#
# ----- Episode 31 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -159729.0 - Epsilon: 0.5
# Training...
# Simulation time: 55.7 s - Training time: 297.8 s - Total: 353.5 s
#
# ----- Episode 32 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -115548.0 - Epsilon: 0.48
# Training...
# Simulation time: 60.5 s - Training time: 307.4 s - Total: 367.9 s
#
# ----- Episode 33 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -103758.0 - Epsilon: 0.47
# Training...
# Simulation time: 57.4 s - Training time: 306.3 s - Total: 363.7 s
#
# ----- Episode 34 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -91676.0 - Epsilon: 0.45
# Training...
# Simulation time: 58.1 s - Training time: 303.9 s - Total: 362.0 s
#
# ----- Episode 35 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -104677.0 - Epsilon: 0.43
# Training...
# Simulation time: 56.2 s - Training time: 287.9 s - Total: 344.1 s
#
# ----- Episode 36 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -171728.0 - Epsilon: 0.42
# Training...
# Simulation time: 60.4 s - Training time: 289.1 s - Total: 349.5 s
#
# ----- Episode 37 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -100989.0 - Epsilon: 0.4
# Training...
# Simulation time: 62.9 s - Training time: 287.7 s - Total: 350.6 s
#
# ----- Episode 38 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -101492.0 - Epsilon: 0.38
# Training...
# Simulation time: 59.8 s - Training time: 293.6 s - Total: 353.4 s
#
# ----- Episode 39 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -148465.0 - Epsilon: 0.37
# Training...
# Simulation time: 63.2 s - Training time: 297.3 s - Total: 360.5 s
#
# ----- Episode 40 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -128519.0 - Epsilon: 0.35
# Training...
# Simulation time: 70.6 s - Training time: 327.3 s - Total: 397.9 s
#
# ----- Episode 41 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -114015.0 - Epsilon: 0.33
# Training...
# Simulation time: 74.2 s - Training time: 310.9 s - Total: 385.1 s
#
# ----- Episode 42 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -110165.0 - Epsilon: 0.32
# Training...
# Simulation time: 65.8 s - Training time: 310.0 s - Total: 375.8 s
#
# ----- Episode 43 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -102293.0 - Epsilon: 0.3
# Training...
# Simulation time: 66.6 s - Training time: 311.7 s - Total: 378.3 s
#
# ----- Episode 44 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -98331.0 - Epsilon: 0.28
# Training...
# Simulation time: 72.0 s - Training time: 302.8 s - Total: 374.8 s
#
# ----- Episode 45 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -97808.0 - Epsilon: 0.27
# Training...
# Simulation time: 63.9 s - Training time: 280.1 s - Total: 344.0 s
#
# ----- Episode 46 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -88779.0 - Epsilon: 0.25
# Training...
# Simulation time: 69.5 s - Training time: 282.3 s - Total: 351.8 s
#
# ----- Episode 47 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -95836.0 - Epsilon: 0.23
# Training...
# Simulation time: 72.1 s - Training time: 306.3 s - Total: 378.4 s
#
# ----- Episode 48 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -88014.0 - Epsilon: 0.22
# Training...
# Simulation time: 81.5 s - Training time: 297.4 s - Total: 378.9 s
#
# ----- Episode 49 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -82131.0 - Epsilon: 0.2
# Training...
# Simulation time: 77.6 s - Training time: 290.8 s - Total: 368.4 s
#
# ----- Episode 50 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -74236.0 - Epsilon: 0.18
# Training...
# Simulation time: 73.3 s - Training time: 286.8 s - Total: 360.1 s
#
# ----- Episode 51 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -83310.0 - Epsilon: 0.17
# Training...
# Simulation time: 79.9 s - Training time: 296.5 s - Total: 376.4 s
#
# ----- Episode 52 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -82507.0 - Epsilon: 0.15
# Training...
# Simulation time: 80.1 s - Training time: 304.7 s - Total: 384.8 s
#
# ----- Episode 53 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -72969.0 - Epsilon: 0.13
# Training...
# Simulation time: 89.8 s - Training time: 296.6 s - Total: 386.4 s
#
# ----- Episode 54 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -81637.0 - Epsilon: 0.12
# Training...
# Simulation time: 76.3 s - Training time: 320.4 s - Total: 396.7 s
#
# ----- Episode 55 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -174989.0 - Epsilon: 0.1
# Training...
# Simulation time: 91.6 s - Training time: 318.2 s - Total: 409.8 s
#
# ----- Episode 56 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -82744.0 - Epsilon: 0.08
# Training...
# Simulation time: 87.3 s - Training time: 302.2 s - Total: 389.5 s
#
# ----- Episode 57 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -146268.0 - Epsilon: 0.07
# Training...
# Simulation time: 82.7 s - Training time: 294.5 s - Total: 377.2 s
#
# ----- Episode 58 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -53163.0 - Epsilon: 0.05
# Training...
# Simulation time: 83.3 s - Training time: 293.0 s - Total: 376.3 s
#
# ----- Episode 59 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -83400.0 - Epsilon: 0.03
# Training...
# Simulation time: 81.4 s - Training time: 301.6 s - Total: 383.0 s
#
# ----- Episode 60 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -67015.0 - Epsilon: 0.02
# Training...
# Simulation time: 91.0 s - Training time: 360.1 s - Total: 451.1 s
#
# ----- Start time: 2021-10-13 14:22:22.776847
# ----- End time: 2021-10-13 20:07:51.371070
# ----- Session info saved at: /content/models/model_3/
