# %%
# !rm -r *
# !add-apt-repository ppa:sumo/stable -y
# !apt-get update -y
# !apt-get install sumo sumo-tools sumo-doc
# !pip install traci
import os
os.environ['SUMO_HOME'] = "/usr/share/sumo/"
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [634 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,418 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,188 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [473 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,221 kB]
# Get:21 http://ppa.launchpad.net/sumo/stable/ubuntu bionic InRelease [15.4 kB]
# Get:22 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,777 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,657 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [506 kB]
# Get:25 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [909 kB]
# Get:26 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [40.9 kB]
# Get:27 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [41.5 kB]
# Get:28 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 Packages [1,156 B]
# Fetched 13.2 MB in 5s (2,458 kB/s)
# Reading package lists... Done
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:16 http://ppa.launchpad.net/sumo/stable/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   binfmt-support fastjar jarwrapper javascript-common libfox-1.6-0
#   libjs-jquery libjs-openlayers libjs-underscore libspatialindex-c4v5
#   libspatialindex-dev libspatialindex4v5 python3-pkg-resources python3-pyproj
#   python3-rtree
# Suggested packages:
#   apache2 | lighttpd | httpd python3-setuptools
# The following NEW packages will be installed:
#   binfmt-support fastjar jarwrapper javascript-common libfox-1.6-0
#   libjs-jquery libjs-openlayers libjs-underscore libspatialindex-c4v5
#   libspatialindex-dev libspatialindex4v5 python3-pkg-resources python3-pyproj
#   python3-rtree sumo sumo-doc sumo-tools
# 0 upgraded, 17 newly installed, 0 to remove and 89 not upgraded.
# Need to get 75.4 MB of archives.
# After this operation, 255 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo amd64 1.9.2+dfsg1-1~bionic [13.7 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 binfmt-support amd64 2.1.8-2 [51.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fastjar amd64 2:0.98-6build1 [66.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 jarwrapper all 0.72.1~18.04.1 [20.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfox-1.6-0 amd64 1.6.56-1 [875 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjs-underscore all 1.8.3~dfsg-1ubuntu0.1 [60.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex4v5 amd64 1.8.5-5 [219 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex-c4v5 amd64 1.8.5-5 [51.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pyproj amd64 1.9.5.1-3build1 [40.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex-dev amd64 1.8.5-5 [285 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-rtree all 0.8.3+ds-1 [16.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-openlayers all 2.13.1+ds2-4 [704 kB]
# Get:16 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo-doc all 1.9.2+dfsg1-1~bionic [37.8 MB]
# Get:17 http://ppa.launchpad.net/sumo/stable/ubuntu bionic/main amd64 sumo-tools all 1.9.2+dfsg1-1~bionic [21.2 MB]
# Fetched 75.4 MB in 7s (10.9 MB/s)
# Selecting previously unselected package binfmt-support.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../00-binfmt-support_2.1.8-2_amd64.deb ...
# Unpacking binfmt-support (2.1.8-2) ...
# Selecting previously unselected package fastjar.
# Preparing to unpack .../01-fastjar_2%3a0.98-6build1_amd64.deb ...
# Unpacking fastjar (2:0.98-6build1) ...
# Selecting previously unselected package jarwrapper.
# Preparing to unpack .../02-jarwrapper_0.72.1~18.04.1_all.deb ...
# Unpacking jarwrapper (0.72.1~18.04.1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../03-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libfox-1.6-0:amd64.
# Preparing to unpack .../04-libfox-1.6-0_1.6.56-1_amd64.deb ...
# Unpacking libfox-1.6-0:amd64 (1.6.56-1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../05-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../06-libjs-underscore_1.8.3~dfsg-1ubuntu0.1_all.deb ...
# Unpacking libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Selecting previously unselected package libspatialindex4v5:amd64.
# Preparing to unpack .../07-libspatialindex4v5_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex4v5:amd64 (1.8.5-5) ...
# Selecting previously unselected package libspatialindex-c4v5:amd64.
# Preparing to unpack .../08-libspatialindex-c4v5_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex-c4v5:amd64 (1.8.5-5) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../09-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-pyproj.
# Preparing to unpack .../10-python3-pyproj_1.9.5.1-3build1_amd64.deb ...
# Unpacking python3-pyproj (1.9.5.1-3build1) ...
# Selecting previously unselected package libspatialindex-dev:amd64.
# Preparing to unpack .../11-libspatialindex-dev_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex-dev:amd64 (1.8.5-5) ...
# Selecting previously unselected package python3-rtree.
# Preparing to unpack .../12-python3-rtree_0.8.3+ds-1_all.deb ...
# Unpacking python3-rtree (0.8.3+ds-1) ...
# Selecting previously unselected package sumo.
# Preparing to unpack .../13-sumo_1.9.2+dfsg1-1~bionic_amd64.deb ...
# Unpacking sumo (1.9.2+dfsg1-1~bionic) ...
# Selecting previously unselected package sumo-doc.
# Preparing to unpack .../14-sumo-doc_1.9.2+dfsg1-1~bionic_all.deb ...
# Unpacking sumo-doc (1.9.2+dfsg1-1~bionic) ...
# Selecting previously unselected package libjs-openlayers.
# Preparing to unpack .../15-libjs-openlayers_2.13.1+ds2-4_all.deb ...
# Unpacking libjs-openlayers (2.13.1+ds2-4) ...
# Selecting previously unselected package sumo-tools.
# Preparing to unpack .../16-sumo-tools_1.9.2+dfsg1-1~bionic_all.deb ...
# Unpacking sumo-tools (1.9.2+dfsg1-1~bionic) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up binfmt-support (2.1.8-2) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/binfmt-support.service → /lib/systemd/system/binfmt-support.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libspatialindex4v5:amd64 (1.8.5-5) ...
# Setting up libfox-1.6-0:amd64 (1.6.56-1) ...
# Setting up libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Setting up fastjar (2:0.98-6build1) ...
# Setting up libjs-openlayers (2.13.1+ds2-4) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up sumo (1.9.2+dfsg1-1~bionic) ...
# Setting up libspatialindex-c4v5:amd64 (1.8.5-5) ...
# Setting up python3-pyproj (1.9.5.1-3build1) ...
# Setting up javascript-common (11) ...
# Setting up jarwrapper (0.72.1~18.04.1) ...
# Setting up sumo-doc (1.9.2+dfsg1-1~bionic) ...
# Setting up libspatialindex-dev:amd64 (1.8.5-5) ...
# Setting up python3-rtree (0.8.3+ds-1) ...
# Setting up sumo-tools (1.9.2+dfsg1-1~bionic) ...
# Processing triggers for systemd (237-3ubuntu10.47) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting traci
#   Downloading https://files.pythonhosted.org/packages/fe/61/c0ab67e2abc7915388b1e8c79d41869300b6dd49e491dfce5a4f816e08c4/traci-1.9.2-py3-none-any.whl (231kB)
#      |████████████████████████████████| 235kB 7.4MB/s
# Collecting sumolib>=1.9.2
#   Downloading https://files.pythonhosted.org/packages/43/f0/ac3622ec3a71b9066b03e94feaf4fcab2d0abd316e6ddd9d94cfe29815ee/sumolib-1.9.2-py3-none-any.whl (144kB)
#      |████████████████████████████████| 153kB 12.0MB/s
# Installing collected packages: sumolib, traci
# Successfully installed sumolib-1.9.2 traci-1.9.2

# %%
# !python training_main.py
# Out:
# ----- Episode 1 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -304591.0 - Epsilon: 1.0
# Training...
# Simulation time: 19.6 s - Training time: 0.0 s - Total: 19.6 s
#
# ----- Episode 2 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -392096.0 - Epsilon: 0.98
# Training...
# Simulation time: 23.7 s - Training time: 172.0 s - Total: 195.7 s
#
# ----- Episode 3 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -248144.0 - Epsilon: 0.97
# Training...
# Simulation time: 19.0 s - Training time: 174.5 s - Total: 193.5 s
#
# ----- Episode 4 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -268874.0 - Epsilon: 0.95
# Training...
# Simulation time: 20.9 s - Training time: 174.5 s - Total: 195.4 s
#
# ----- Episode 5 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -236502.0 - Epsilon: 0.93
# Training...
# Simulation time: 20.5 s - Training time: 175.9 s - Total: 196.4 s
#
# ----- Episode 6 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -227570.0 - Epsilon: 0.92
# Training...
# Simulation time: 20.4 s - Training time: 175.3 s - Total: 195.7 s
#
# ----- Episode 7 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -194807.0 - Epsilon: 0.9
# Training...
# Simulation time: 20.1 s - Training time: 171.0 s - Total: 191.1 s
#
# ----- Episode 8 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -244073.0 - Epsilon: 0.88
# Training...
# Simulation time: 20.8 s - Training time: 169.3 s - Total: 190.1 s
#
# ----- Episode 9 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -267097.0 - Epsilon: 0.87
# Training...
# Simulation time: 22.3 s - Training time: 170.9 s - Total: 193.2 s
#
# ----- Episode 10 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -308663.0 - Epsilon: 0.85
# Training...
# Simulation time: 22.3 s - Training time: 170.9 s - Total: 193.2 s
#
# ----- Episode 11 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -519437.0 - Epsilon: 0.83
# Training...
# Simulation time: 29.1 s - Training time: 168.4 s - Total: 197.5 s
#
# ----- Episode 12 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -274751.0 - Epsilon: 0.82
# Training...
# Simulation time: 22.4 s - Training time: 167.9 s - Total: 190.3 s
#
# ----- Episode 13 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -216670.0 - Epsilon: 0.8
# Training...
# Simulation time: 23.3 s - Training time: 168.3 s - Total: 191.6 s
#
# ----- Episode 14 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -222032.0 - Epsilon: 0.78
# Training...
# Simulation time: 23.0 s - Training time: 167.5 s - Total: 190.5 s
#
# ----- Episode 15 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -325008.0 - Epsilon: 0.77
# Training...
# Simulation time: 24.8 s - Training time: 168.5 s - Total: 193.3 s
#
# ----- Episode 16 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -297513.0 - Epsilon: 0.75
# Training...
# Simulation time: 25.0 s - Training time: 168.5 s - Total: 193.5 s
#
# ----- Episode 17 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -160325.0 - Epsilon: 0.73
# Training...
# Simulation time: 23.4 s - Training time: 168.1 s - Total: 191.5 s
#
# ----- Episode 18 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -355950.0 - Epsilon: 0.72
# Training...
# Simulation time: 25.4 s - Training time: 168.2 s - Total: 193.6 s
#
# ----- Episode 19 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -182081.0 - Epsilon: 0.7
# Training...
# Simulation time: 23.3 s - Training time: 168.0 s - Total: 191.3 s
#
# ----- Episode 20 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -296231.0 - Epsilon: 0.68
# Training...
# Simulation time: 27.2 s - Training time: 168.2 s - Total: 195.4 s
#
# ----- Episode 21 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -327369.0 - Epsilon: 0.67
# Training...
# Simulation time: 29.8 s - Training time: 167.8 s - Total: 197.6 s
#
# ----- Episode 22 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -158530.0 - Epsilon: 0.65
# Training...
# Simulation time: 23.6 s - Training time: 169.5 s - Total: 193.1 s
#
# ----- Episode 23 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -221734.0 - Epsilon: 0.63
# Training...
# Simulation time: 28.7 s - Training time: 167.4 s - Total: 196.1 s
#
# ----- Episode 24 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -174843.0 - Epsilon: 0.62
# Training...
# Simulation time: 26.8 s - Training time: 169.1 s - Total: 195.9 s
#
# ----- Episode 25 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -210562.0 - Epsilon: 0.6
# Training...
# Simulation time: 26.9 s - Training time: 170.0 s - Total: 196.9 s
#
# ----- Episode 26 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -178612.0 - Epsilon: 0.58
# Training...
# Simulation time: 26.6 s - Training time: 173.5 s - Total: 200.1 s
#
# ----- Episode 27 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -194056.0 - Epsilon: 0.57
# Training...
# Simulation time: 26.8 s - Training time: 173.0 s - Total: 199.8 s
#
# ----- Episode 28 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -167070.0 - Epsilon: 0.55
# Training...
# Simulation time: 26.5 s - Training time: 172.5 s - Total: 199.0 s
#
# ----- Episode 29 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -143511.0 - Epsilon: 0.53
# Training...
# Simulation time: 26.2 s - Training time: 173.3 s - Total: 199.5 s
#
# ----- Episode 30 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -152035.0 - Epsilon: 0.52
# Training...
# Simulation time: 28.4 s - Training time: 172.5 s - Total: 200.9 s
#
# ----- Episode 31 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -138631.0 - Epsilon: 0.5
# Training...
# Simulation time: 27.9 s - Training time: 171.6 s - Total: 199.5 s
#
# ----- Episode 32 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -148457.0 - Epsilon: 0.48
# Training...
# Simulation time: 30.4 s - Training time: 172.4 s - Total: 202.8 s
#
# ----- Episode 33 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -170826.0 - Epsilon: 0.47
# Training...
# Simulation time: 29.1 s - Training time: 173.1 s - Total: 202.2 s
#
# ----- Episode 34 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -320696.0 - Epsilon: 0.45
# Training...
# Simulation time: 32.5 s - Training time: 172.7 s - Total: 205.2 s
#
# ----- Episode 35 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -151326.0 - Epsilon: 0.43
# Training...
# Simulation time: 29.8 s - Training time: 173.0 s - Total: 202.8 s
#
# ----- Episode 36 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -388390.0 - Epsilon: 0.42
# Training...
# Simulation time: 38.6 s - Training time: 174.1 s - Total: 212.7 s
#
# ----- Episode 37 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -253031.0 - Epsilon: 0.4
# Training...
# Simulation time: 32.7 s - Training time: 173.1 s - Total: 205.8 s
#
# ----- Episode 38 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -142903.0 - Epsilon: 0.38
# Training...
# Simulation time: 31.0 s - Training time: 173.2 s - Total: 204.2 s
#
# ----- Episode 39 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -206624.0 - Epsilon: 0.37
# Training...
# Simulation time: 32.1 s - Training time: 172.4 s - Total: 204.5 s
#
# ----- Episode 40 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -322213.0 - Epsilon: 0.35
# Training...
# Simulation time: 38.1 s - Training time: 173.7 s - Total: 211.8 s
#
# ----- Episode 41 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -318775.0 - Epsilon: 0.33
# Training...
# Simulation time: 36.6 s - Training time: 174.0 s - Total: 210.6 s
#
# ----- Episode 42 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -134092.0 - Epsilon: 0.32
# Training...
# Simulation time: 31.4 s - Training time: 173.7 s - Total: 205.1 s
#
# ----- Episode 43 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -111404.0 - Epsilon: 0.3
# Training...
# Simulation time: 32.1 s - Training time: 173.6 s - Total: 205.7 s
#
# ----- Episode 44 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -136979.0 - Epsilon: 0.28
# Training...
# Simulation time: 33.4 s - Training time: 173.2 s - Total: 206.6 s
#
# ----- Episode 45 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -142386.0 - Epsilon: 0.27
# Training...
# Simulation time: 33.7 s - Training time: 173.6 s - Total: 207.3 s
#
# ----- Episode 46 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -152382.0 - Epsilon: 0.25
# Training...
# Simulation time: 33.4 s - Training time: 173.2 s - Total: 206.6 s
#
# ----- Episode 47 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -206990.0 - Epsilon: 0.23
# Training...
# Simulation time: 37.6 s - Training time: 173.3 s - Total: 210.9 s
#
# ----- Episode 48 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -114260.0 - Epsilon: 0.22
# Training...
# Simulation time: 33.8 s - Training time: 172.5 s - Total: 206.3 s
#
# ----- Episode 49 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -268779.0 - Epsilon: 0.2
# Training...
# Simulation time: 39.7 s - Training time: 173.2 s - Total: 212.9 s
#
# ----- Episode 50 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -228940.0 - Epsilon: 0.18
# Training...
# Simulation time: 38.1 s - Training time: 172.9 s - Total: 211.0 s
#
# ----- Episode 51 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -174753.0 - Epsilon: 0.17
# Training...
# Simulation time: 36.9 s - Training time: 175.8 s - Total: 212.7 s
#
# ----- Episode 52 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -126540.0 - Epsilon: 0.15
# Training...
# Simulation time: 34.5 s - Training time: 172.9 s - Total: 207.4 s
#
# ----- Episode 53 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -152339.0 - Epsilon: 0.13
# Training...
# Simulation time: 37.0 s - Training time: 179.3 s - Total: 216.3 s
#
# ----- Episode 54 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -204996.0 - Epsilon: 0.12
# Training...
# Simulation time: 38.1 s - Training time: 176.4 s - Total: 214.5 s
#
# ----- Episode 55 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -321936.0 - Epsilon: 0.1
# Training...
# Simulation time: 44.0 s - Training time: 177.4 s - Total: 221.4 s
#
# ----- Episode 56 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -138655.0 - Epsilon: 0.08
# Training...
# Simulation time: 39.9 s - Training time: 187.7 s - Total: 227.6 s
#
# ----- Episode 57 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -232462.0 - Epsilon: 0.07
# Training...
# Simulation time: 43.9 s - Training time: 185.9 s - Total: 229.8 s
#
# ----- Episode 58 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -216912.0 - Epsilon: 0.05
# Training...
# Simulation time: 41.8 s - Training time: 178.2 s - Total: 220.0 s
#
# ----- Episode 59 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -166080.0 - Epsilon: 0.03
# Training...
# Simulation time: 40.4 s - Training time: 177.8 s - Total: 218.2 s
#
# ----- Episode 60 of 60
#  Retrying in 1 seconds
# Loading configuration ... done.
# Simulating...
# Total reward: -164701.0 - Epsilon: 0.02
# Training...
# Simulation time: 40.4 s - Training time: 174.8 s - Total: 215.2 s
#
# ----- Start time: 2021-07-03 16:44:25.816086
# ----- End time: 2021-07-03 20:04:14.088027
# ----- Session info saved at: /content/models/model_1/
